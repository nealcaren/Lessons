# %% [markdown]
# ## Undocument APIs
#
# [**Neal Caren**](mailto:neal.caren@gmail.com)
# University of North Carolina, Chapel Hill

# %% [markdown]
# Social scientists are often interested in collecting massive amounts of digital data from specific websites. When you are fortunate, someone else has already scrapped it for you and has released in on [GitHub](https://github.com) or as a [Kaggle dataset](https://www.kaggle.com/datasets). Sometimes the website provides an [API](https://en.wikipedia.org/wiki/Web_API), an interface for collecting the data in a systematic way that is usually reasonably well-document. The most prominent of these for social scientists is probably [Twitter](https://developer.twitter.com/en/docs.html), who have enabled hundreds of academic studies by making available information about posts and users.
#
# Other times, an API exists and is being used by the website, but information about is not publicly available. Most website searches, for example, involve using an internal web API. Your search term, along with other relevant parameters, is used to extract the corresponding results from a dataset and then displayed on a web page. While we see the data as part of a web page, the data is often transmitted in a different, more research-friend format, usually in a [JSON](https://en.wikipedia.org/wiki/JSON) format. Using an undocumented API allows you to systematically collect the data without the parsing the HTML of each page.
#
# Below, I walk through the steps I recently used  when trying to gather Fox News Opinion articles. In this case, the API doesn't return the full text of the articles, but, as is often the case, returns all the metadata about the article, including the article URL for subsequent scraping.
#
# I use Python, but the overall logic is similar for other languages.

# %% [markdown]
# I begin by enabling the developer toolbar on my browser. In Safari, this is under **Preferences->Advanced** and then clicking **Show Develop Menu in Menu Bar**. The process is similar in Chrome.

# %% [markdown]
# I visited the front page.
# ![frontpage](images/frontpage.png)

# %% [markdown]
# I clicked on **Opinion**, the section I wanted to scrape.
# ![opinion](images/opinion.png)

# %% [markdown]
# I scrolled down the page and found a list of articles with a **Show More** button. This type of button, which leads to the next set of results, is a key component for understanding how the webpage is structured.
# ![more.png](images/more.png)

# %% [markdown]
# In this case, **Show More** does not load a new page but it does expand the number of results shown on the existing page. If you copy the link associated with this button (`https://www.foxnews.com/opinion#`) and paste it in a new browser window, it merely displays the first set of results, so that is a dead end for uncovering an API.
#
# To be confident that there might be a decent number of articles available, I clicked the **Show More** button several times. Each time it loaded more articles.
# ![more.png](images/more2.png)

# %% [markdown]
# Lots of data is passed between my computer and the Foxnews website with each click. Additional information about these streams can be revealed through the **Develop** menu and then the **Show Page Resources** option.
#
# ![develop.png](images/develop.png)

# %% [markdown]
# This defaults to showing the page's HTML code.
# ![html.png](images/html.png)

# %% [markdown]
# To look for signs of an API, I click on the **Network** tab. Results are sometimes already listed, but I start clean by using the trash icon on the far right. With the **Network** tab visible, I then click **Show More** on the web page. Each resource exchanged between my computer and various servers are now displayed. When the action stops, I sort the list by size.
# ![network.png](images/network1.png)

# %% [markdown]
# I now review each of the items for something that looks like the results of search API, a plain text file with the search results.
#
# Usually, the top of the list displays the images that the page retrieved. Images usually have a .png or .jpg extension. Selecting the first item in the results, an JPG with a name full of numbers, confirms that it is a picture.
#
# ![image.png](images/network_image.png)

# %% [markdown]
# The name of the second item, **article-search** has more promise. The **Preview** tab shows that this is a JSON object that appears to be a list of the articles that were returned after the **Show More** button was pressed. Bingo!
#
# ![image.png](images/network_search.png)

# %% [markdown]
# The **Header** tab reveals the specific URL that returned this JSON.
# ![image.png](images/network_header.png)

# %% [markdown]
# The URL has all the signs of an undocumented API. First, it contains "API" as part of the string. Second, it includes a series of search parameters, such as `isCategory` and `size`.  Now I copy the URL and paste and save it as a Python string. I split the string over several lines to view it more clearly.

# %%
url = ('https://www.foxnews.com/api/article-search?'
       'isCategory=true&isTag=false&isKeyword=false&'
       'isFixed=false&isFeedUrl=false&searchSelected=opinion&'
       'contentTypes=%7B%22interactive%22:true,%22slideshow%22:true,%22video%22:false,%22article%22:true%7D&'
       'size=11&offset=30')

# %% [markdown]
# The next step is to see if Python can access the API with a straightforward command. Some APIs require confirmation that the search is originating from original websites, while others do not enforce that. Figuring out the right way to programmatically access the website is a process of trial and error. I use the `requests` library.

# %%
import requests

r = requests.get(url)
r.status_code
# Out:
# 200

# %% [markdown]
# A status code of 200 means that something was returned.
#
# Since it looked like a JSON object when viewed in the browser, I take advantage of the `requests` JSON decoder.

# %%
r.json()
# Out:
# [{'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'Rep. Ilhan Omar sparked outrage Sunday from both Democrats and Republicans after asserting on Twitter that U.S. support for Israel is based on monetary support from Jewish groups, especially AIPAC, the American Israel Public Affairs Committee.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/11/348/196/694940094001_6000812878001_6000814671001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T13:42:01-05:00',
#   'publicationDate': '2019-02-11T13:42:01-05:00',
#   'title': "Democrats allowing Ilhan Omar's anti-Semitic rhetoric to be standard-bearer for the party",
#   'url': '/opinion/democrats-allowing-ilhan-omars-anti-semitic-rhetoric-to-be-standard-bearer-for-the-party'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'I’m a member of the U.S. House of Representatives who is pro-life. But I’m more than just a politician reciting pro-life talking points. I’m also a physician who has delivered 5,000 babies and spent 30 years caring for expecting mothers and guiding families through pregnancy.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/01/23/348/196/694940094001_5993052133001_5993052587001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T13:22:58-05:00',
#   'publicationDate': '2019-02-11T13:22:58-05:00',
#   'title': "Rep. Roger Marshall: NY abortion law is a danger to mothers – I know, as a doctor who's delivered 5,000 babies",
#   'url': '/opinion/new-yorks-late-term-abortion-law-is-a-danger-to-mothers-i-know-as-a-doctor-whos-delivered-5000-babies'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'Neomi Rao is President Trump’s nominee for the D.C. Circuit Court of Appeals, a federal court that is generally recognized as the second-most important court in the nation. Four sitting Supreme Court justices previously sat on the D.C. Circuit.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/05/348/196/694940094001_5998420399001_5998423526001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T12:19:19-05:00',
#   'publicationDate': '2019-02-11T12:19:19-05:00',
#   'title': "Democrats' attacks on Kavanaugh replacement Neomi Rao are unfair – I was nearly raped and I support her",
#   'url': '/opinion/democrats-overreach-again-in-attacking-neomi-rao'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'It’s open season on white males at Yale University.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/static.foxnews.com/foxnews.com/content/uploads/2018/09/348/196/rts6pqx.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T12:02:00-05:00',
#   'publicationDate': '2019-02-11T12:02:00-05:00',
#   'title': 'Have American universities become breeding grounds for anti-white hate?',
#   'url': '/opinion/have-american-universities-become-breeding-grounds-for-anti-white-hate'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'Democrats need an identity-politics intervention. Having unleashed race, gender, sexual orientation and class as the defining issues of American politics, these furies are now consuming their authors.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/08/348/196/694940094001_6000152260001_6000145134001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T10:20:04-05:00',
#   'publicationDate': '2019-02-11T10:20:04-05:00',
#   'title': "Democrats' are having an identity meltdown -- The furies they've unleashed are consuming them. Where's Obama?",
#   'url': '/opinion/democrats-are-having-an-identity-meltdown-the-furies-theyve-unleashed-are-consuming-them-wheres-obama'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'For proof that Trump is not the root of all madness, consider the spectacles Democrats created in two states.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/11/348/196/694940094001_6000808473001_6000803956001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T07:48:14-05:00',
#   'publicationDate': '2019-02-11T07:48:14-05:00',
#   'title': "Trump's sanity highlighted by Democrats' crazy, disastrous spectacles in two states",
#   'url': '/opinion/trumps-sanity-highlighted-by-democrats-crazy-disastrous-spectacles-in-two-states'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'Republicans have found their platform for 2020, and they have Democrats to thank.\xa0After a month in which a partial government shutdown battered President Trump’s approval ratings, a string of self-inflicted wounds by Democrats has abruptly shifted the political landscape, resuscitating discouraged Republicans and also setting the debate for 2020.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/11/348/196/694940094001_6000854422001_6000854722001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T06:59:52-05:00',
#   'publicationDate': '2019-02-11T06:59:52-05:00',
#   'title': "Liz Peek: GOP's 2020 campaign will put Dem extremism on trial",
#   'url': '/opinion/liz-peek-gops-2020-campaign-will-put-dem-extremism-on-trial'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'For a while, I’ve wanted to say what I think about race in America -- as an immigrant, as an outsider -- and as a believer in positive populism.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/11/348/196/694940094001_6000619322001_6000627552001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T06:41:46-05:00',
#   'publicationDate': '2019-02-11T06:41:46-05:00',
#   'title': 'Steve Hilton: The Democratic racism scandal in Virginia and what Trump can do to heal our racial divide',
#   'url': '/opinion/steve-hilton-the-democratic-racism-scandal-in-virginia-and-what-trump-can-do-to-heal-our-racial-divide'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'Hours after Massachusetts Democrat Sen. Elizabeth Warren kicked off her 2020 campaign, President Trump tweeted he would see her on the “trail,” twisting the knife deeper into a potent political wound.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/10/348/196/694940094001_6000404199001_6000410243001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-11T04:00:38-05:00',
#   'publicationDate': '2019-02-11T04:00:38-05:00',
#   'title': '2020 Election: THIS is the Democrat Trump would most like to run against',
#   'url': '/opinion/2020-election-this-is-the-democrat-trump-would-most-like-to-run-against'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'If I were advising our Houses of Congress on how to become a more effective, more efficient branch of our government, I’d ask our representatives to remember who they’re here to serve, and then have them start asking the following questions:',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/static.foxnews.com/foxnews.com/content/uploads/2019/01/348/196/AP19003650577556.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-10T23:18:53-05:00',
#   'publicationDate': '2019-02-10T23:18:53-05:00',
#   'title': "I'm a corporate coach -- Here's how we can get Congress to work again",
#   'url': '/opinion/im-a-corporate-coach-heres-how-we-can-get-congress-to-work-again'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'The similarity between the left’s greens and reds became as clear as black and white this week. And the press failed miserably at making the connection.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/09/348/196/694940094001_6000302469001_6000296740001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-10T22:46:52-05:00',
#   'publicationDate': '2019-02-10T22:46:52-05:00',
#   'title': "Worst media moments of the week: Press just can't be honest about the Green New Deal and much more",
#   'url': '/opinion/worst-media-moments-of-the-week-press-just-cant-be-honest-about-the-green-new-deal-and-much-more'}]

# %% [markdown]
# The best way to turn a JSON into usable a format is with the `pandas` library.

# %%
import pandas as pd

df = pd.DataFrame(r.json())

# %%
df.head()
# Out:
#                                           category  \
# 0  {'name': 'OPINION', 'url': '/category/opinion'}
# 1  {'name': 'OPINION', 'url': '/category/opinion'}
# 2  {'name': 'OPINION', 'url': '/category/opinion'}
# 3  {'name': 'OPINION', 'url': '/category/opinion'}
# 4  {'name': 'OPINION', 'url': '/category/opinion'}
#
#                                          description duration  \
# 0  Rep. Ilhan Omar sparked outrage Sunday from bo...
# 1  I’m a member of the U.S. House of Representati...
# 2  Neomi Rao is President Trump’s nominee for the...
# 3  It’s open season on white males at Yale Univer...
# 4  Democrats need an identity-politics interventi...
#
#                                             imageUrl  isBreaking  isLive  \
# 0  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#            lastPublishedDate            publicationDate  \
# 0  2019-02-11T13:42:01-05:00  2019-02-11T13:42:01-05:00
# 1  2019-02-11T13:22:58-05:00  2019-02-11T13:22:58-05:00
# 2  2019-02-11T12:19:19-05:00  2019-02-11T12:19:19-05:00
# 3  2019-02-11T12:02:00-05:00  2019-02-11T12:02:00-05:00
# 4  2019-02-11T10:20:04-05:00  2019-02-11T10:20:04-05:00
#
#                                                title  \
# 0  Democrats allowing Ilhan Omar's anti-Semitic r...
# 1  Rep. Roger Marshall: NY abortion law is a dang...
# 2  Democrats' attacks on Kavanaugh replacement Ne...
# 3  Have American universities become breeding gro...
# 4  Democrats' are having an identity meltdown -- ...
#
#                                                  url
# 0  /opinion/democrats-allowing-ilhan-omars-anti-s...
# 1  /opinion/new-yorks-late-term-abortion-law-is-a...
# 2  /opinion/democrats-overreach-again-in-attackin...
# 3  /opinion/have-american-universities-become-bre...
# 4  /opinion/democrats-are-having-an-identity-melt...

# %% [markdown]
# That looks pretty good. The JSON appears to have some nested elements in it. For example, Category contains a dictionary. These can often be flattened with `json_normalize`.

# %%
from pandas.io.json import json_normalize

df = json_normalize(r.json())

df.head()
# Out:
#   category.name       category.url  \
# 0       OPINION  /category/opinion
# 1       OPINION  /category/opinion
# 2       OPINION  /category/opinion
# 3       OPINION  /category/opinion
# 4       OPINION  /category/opinion
#
#                                          description duration  \
# 0  Rep. Ilhan Omar sparked outrage Sunday from bo...
# 1  I’m a member of the U.S. House of Representati...
# 2  Neomi Rao is President Trump’s nominee for the...
# 3  It’s open season on white males at Yale Univer...
# 4  Democrats need an identity-politics interventi...
#
#                                             imageUrl  isBreaking  isLive  \
# 0  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#            lastPublishedDate            publicationDate  \
# 0  2019-02-11T13:42:01-05:00  2019-02-11T13:42:01-05:00
# 1  2019-02-11T13:22:58-05:00  2019-02-11T13:22:58-05:00
# 2  2019-02-11T12:19:19-05:00  2019-02-11T12:19:19-05:00
# 3  2019-02-11T12:02:00-05:00  2019-02-11T12:02:00-05:00
# 4  2019-02-11T10:20:04-05:00  2019-02-11T10:20:04-05:00
#
#                                                title  \
# 0  Democrats allowing Ilhan Omar's anti-Semitic r...
# 1  Rep. Roger Marshall: NY abortion law is a dang...
# 2  Democrats' attacks on Kavanaugh replacement Ne...
# 3  Have American universities become breeding gro...
# 4  Democrats' are having an identity meltdown -- ...
#
#                                                  url
# 0  /opinion/democrats-allowing-ilhan-omars-anti-s...
# 1  /opinion/new-yorks-late-term-abortion-law-is-a...
# 2  /opinion/democrats-overreach-again-in-attackin...
# 3  /opinion/have-american-universities-become-bre...
# 4  /opinion/democrats-are-having-an-identity-melt...

# %% [markdown]
# Great! This process demonstrates that FoxNews has an undocumented API that can be accessed via Python. The dataset, however, only has a few cases.

# %%
len(df)
# Out:
# 11

# %% [markdown]
# The next step is to see if more data can be collected. I usually focus on two parameters: How do I get to the next set of results? Can I get more results with each call?

# %%
print(url)
# Out:
# https://www.foxnews.com/api/article-search?isCategory=true&isTag=false&isKeyword=false&isFixed=false&isFeedUrl=false&searchSelected=opinion&contentTypes=%7B%22interactive%22:true,%22slideshow%22:true,%22video%22:false,%22article%22:true%7D&size=11&offset=30

# %% [markdown]
# Looking back at the URL, the likely suspects for manipulation are `size`, which usually determines the number of results, and `offset` which usually means "start with the nth result". I first check to see how many results can be returned in one call. If the answer is 10,000, I don't need to do much more.
#
# Since I'll be making many calls using the API, I write a quick function to take the URL and return a dataframe. Once I'm confident it will work, I would likely make a more robust function that allows more direct manipulation of the parameters, but I don't want to spend too much time on that if the whole API is a dead end.

# %%
def fox_df(url):
    r = requests.get(url)
    df = json_normalize(r.json())
    print('Return a dataframe of length',len(df))
    return df

# %% [markdown]
# I confirm that the function works using the original url.

# %%
fox_df(url)
# Out:
# Return a dataframe of length 11
#    category.name       category.url  \
# 0        OPINION  /category/opinion
# 1        OPINION  /category/opinion
# 2        OPINION  /category/opinion
# 3        OPINION  /category/opinion
# 4        OPINION  /category/opinion
# 5        OPINION  /category/opinion
# 6        OPINION  /category/opinion
# 7        OPINION  /category/opinion
# 8        OPINION  /category/opinion
# 9        OPINION  /category/opinion
# 10       OPINION  /category/opinion
#
#                                           description duration  \
# 0   Rep. Ilhan Omar sparked outrage Sunday from bo...
# 1   I’m a member of the U.S. House of Representati...
# 2   Neomi Rao is President Trump’s nominee for the...
# 3   It’s open season on white males at Yale Univer...
# 4   Democrats need an identity-politics interventi...
# 5   For proof that Trump is not the root of all ma...
# 6   Republicans have found their platform for 2020...
# 7   For a while, I’ve wanted to say what I think a...
# 8   Hours after Massachusetts Democrat Sen. Elizab...
# 9   If I were advising our Houses of Congress on h...
# 10  The similarity between the left’s greens and r...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2019-02-11T13:42:01-05:00  2019-02-11T13:42:01-05:00
# 1   2019-02-11T13:22:58-05:00  2019-02-11T13:22:58-05:00
# 2   2019-02-11T12:19:19-05:00  2019-02-11T12:19:19-05:00
# 3   2019-02-11T12:02:00-05:00  2019-02-11T12:02:00-05:00
# 4   2019-02-11T10:20:04-05:00  2019-02-11T10:20:04-05:00
# 5   2019-02-11T07:48:14-05:00  2019-02-11T07:48:14-05:00
# 6   2019-02-11T06:59:52-05:00  2019-02-11T06:59:52-05:00
# 7   2019-02-11T06:41:46-05:00  2019-02-11T06:41:46-05:00
# 8   2019-02-11T04:00:38-05:00  2019-02-11T04:00:38-05:00
# 9   2019-02-10T23:18:53-05:00  2019-02-10T23:18:53-05:00
# 10  2019-02-10T22:46:52-05:00  2019-02-10T22:46:52-05:00
#
#                                                 title  \
# 0   Democrats allowing Ilhan Omar's anti-Semitic r...
# 1   Rep. Roger Marshall: NY abortion law is a dang...
# 2   Democrats' attacks on Kavanaugh replacement Ne...
# 3   Have American universities become breeding gro...
# 4   Democrats' are having an identity meltdown -- ...
# 5   Trump's sanity highlighted by Democrats' crazy...
# 6   Liz Peek: GOP's 2020 campaign will put Dem ext...
# 7   Steve Hilton: The Democratic racism scandal in...
# 8   2020 Election: THIS is the Democrat Trump woul...
# 9   I'm a corporate coach -- Here's how we can get...
# 10  Worst media moments of the week: Press just ca...
#
#                                                   url
# 0   /opinion/democrats-allowing-ilhan-omars-anti-s...
# 1   /opinion/new-yorks-late-term-abortion-law-is-a...
# 2   /opinion/democrats-overreach-again-in-attackin...
# 3   /opinion/have-american-universities-become-bre...
# 4   /opinion/democrats-are-having-an-identity-melt...
# 5   /opinion/trumps-sanity-highlighted-by-democrat...
# 6   /opinion/liz-peek-gops-2020-campaign-will-put-...
# 7   /opinion/steve-hilton-the-democratic-racism-sc...
# 8   /opinion/2020-election-this-is-the-democrat-tr...
# 9   /opinion/im-a-corporate-coach-heres-how-we-can...
# 10  /opinion/worst-media-moments-of-the-week-press...

# %% [markdown]
# As a first attempt, I try to retrieve 100 results.

# %%
url100 = url.replace('size=11','size=100')

fox_df(url100)
# Out:
# Return a dataframe of length 30
#                  category.name                                category.url  \
# 0                      OPINION                           /category/opinion
# 1                      OPINION                           /category/opinion
# 2                      OPINION                           /category/opinion
# 3                      OPINION                           /category/opinion
# 4                      OPINION                           /category/opinion
# 5                      OPINION                           /category/opinion
# 6                      OPINION                           /category/opinion
# 7                      OPINION                           /category/opinion
# 8                      OPINION                           /category/opinion
# 9                      OPINION                           /category/opinion
# 10                     OPINION                           /category/opinion
# 11                     OPINION                           /category/opinion
# 12                     OPINION                           /category/opinion
# 13  JUSTICE WITH JUDGE JEANINE  /category/shows/justice-with-judge-jeanine
# 14                     OPINION                           /category/opinion
# 15                     OPINION                           /category/opinion
# 16              Faith & Values                      /category/faith-values
# 17                     OPINION                           /category/opinion
# 18                     OPINION                           /category/opinion
# 19                     OPINION                           /category/opinion
# 20                     OPINION                           /category/opinion
# 21                     OPINION                           /category/opinion
# 22                     OPINION                           /category/opinion
# 23                     OPINION                           /category/opinion
# 24                     OPINION                           /category/opinion
# 25                     OPINION                           /category/opinion
# 26                     OPINION                           /category/opinion
# 27                     OPINION                           /category/opinion
# 28                     OPINION                           /category/opinion
# 29                     OPINION                           /category/opinion
#
#                                           description duration  \
# 0   Rep. Ilhan Omar sparked outrage Sunday from bo...
# 1   I’m a member of the U.S. House of Representati...
# 2   Neomi Rao is President Trump’s nominee for the...
# 3   It’s open season on white males at Yale Univer...
# 4   Democrats need an identity-politics interventi...
# 5   For proof that Trump is not the root of all ma...
# 6   Republicans have found their platform for 2020...
# 7   For a while, I’ve wanted to say what I think a...
# 8   Hours after Massachusetts Democrat Sen. Elizab...
# 9   If I were advising our Houses of Congress on h...
# 10  The similarity between the left’s greens and r...
# 11  Border walls have a checkered history of succe...
# 12  After years of political and cultural sparring...
# 13  We are reaching a turning point that will fore...
# 14  While many in religious circles regularly lame...
# 15  The party of aspiring socialists once referred...
# 16  We who are leaders of the Christian faith must...
# 17  Here's a strategy for winning our 40-year-old ...
# 18  For me, immigration is a biblical issue. Our f...
# 19  Marriage starts out with grand vision – a shar...
# 20  If you’re struggling in the dating department,...
# 21  “Do you want us to let him go?” Those were the...
# 22  The State of the Union speech was not delivere...
# 23  President Trump’s State of the Union address w...
# 24  No matter what comes of the racial scandals in...
# 25  The U.S. Attorney;s Office in the Southern Dis...
# 26  Pope Francis' visit to the Arabian Peninsula w...
# 27  I met Mike Monsoor when he checked into SEAL T...
# 28  As Democrats justify grandiose proposals by de...
# 29  I went through a long, dark time a few years a...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 11  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 12  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 13  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 14  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 15  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 16  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 17  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 18  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 19  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 20  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 21  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 22  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 23  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 24  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 25  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 26  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 27  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 28  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 29  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2019-02-11T13:42:01-05:00  2019-02-11T13:42:01-05:00
# 1   2019-02-11T13:22:58-05:00  2019-02-11T13:22:58-05:00
# 2   2019-02-11T12:19:19-05:00  2019-02-11T12:19:19-05:00
# 3   2019-02-11T12:02:00-05:00  2019-02-11T12:02:00-05:00
# 4   2019-02-11T10:20:04-05:00  2019-02-11T10:20:04-05:00
# 5   2019-02-11T07:48:14-05:00  2019-02-11T07:48:14-05:00
# 6   2019-02-11T06:59:52-05:00  2019-02-11T06:59:52-05:00
# 7   2019-02-11T06:41:46-05:00  2019-02-11T06:41:46-05:00
# 8   2019-02-11T04:00:38-05:00  2019-02-11T04:00:38-05:00
# 9   2019-02-10T23:18:53-05:00  2019-02-10T23:18:53-05:00
# 10  2019-02-10T22:46:52-05:00  2019-02-10T22:46:52-05:00
# 11  2019-02-10T21:42:13-05:00  2019-02-10T21:42:13-05:00
# 12  2019-02-10T20:51:29-05:00  2019-02-10T20:51:29-05:00
# 13  2019-02-10T14:58:59-05:00  2019-02-10T14:58:59-05:00
# 14  2019-02-10T13:49:09-05:00  2019-02-10T13:49:09-05:00
# 15  2019-02-10T10:41:56-05:00  2019-02-10T10:41:56-05:00
# 16  2019-02-10T07:27:57-05:00  2019-02-10T07:27:57-05:00
# 17  2019-02-10T04:00:32-05:00  2019-02-10T04:00:32-05:00
# 18  2019-02-10T04:00:31-05:00  2019-02-10T04:00:31-05:00
# 19  2019-02-10T04:00:11-05:00  2019-02-10T04:00:11-05:00
# 20  2019-02-10T04:00:08-05:00  2019-02-10T04:00:08-05:00
# 21  2019-02-09T21:03:40-05:00  2019-02-09T04:00:25-05:00
# 22  2019-02-09T20:03:25-05:00  2019-02-09T20:03:25-05:00
# 23  2019-02-09T18:38:56-05:00  2019-02-09T18:38:56-05:00
# 24  2019-02-09T17:08:48-05:00  2019-02-09T17:08:48-05:00
# 25  2019-02-09T12:47:12-05:00  2019-02-09T12:47:12-05:00
# 26  2019-02-09T11:48:30-05:00  2019-02-09T11:48:30-05:00
# 27  2019-02-09T04:00:55-05:00  2019-02-09T04:00:55-05:00
# 28  2019-02-09T04:00:49-05:00  2019-02-09T04:00:49-05:00
# 29  2019-02-09T04:00:35-05:00  2019-02-09T04:00:35-05:00
#
#                                                 title  \
# 0   Democrats allowing Ilhan Omar's anti-Semitic r...
# 1   Rep. Roger Marshall: NY abortion law is a dang...
# 2   Democrats' attacks on Kavanaugh replacement Ne...
# 3   Have American universities become breeding gro...
# 4   Democrats' are having an identity meltdown -- ...
# 5   Trump's sanity highlighted by Democrats' crazy...
# 6   Liz Peek: GOP's 2020 campaign will put Dem ext...
# 7   Steve Hilton: The Democratic racism scandal in...
# 8   2020 Election: THIS is the Democrat Trump woul...
# 9   I'm a corporate coach -- Here's how we can get...
# 10  Worst media moments of the week: Press just ca...
# 11  Border crisis: America, here's an abbreviated ...
# 12  What do King Tut's tomb and the 21st Century h...
# 13  Judge Jeanine Pirro: Think socialism can never...
# 14  Grammys 2019: Why God will be center stage at ...
# 15  Tomi Lahren: The Democratic Party is absolutel...
# 16  If churches want to get millennials to enter t...
# 17  America should hit Iran where it hurts after 4...
# 18  Pastor: For me, immigration is biblical --  Fo...
# 19  The most important thing you can do for your m...
# 20  Valentine's Day 2019: Drop the drama this year...
# 21  When I was born my parents were told I was 'no...
# 22  Deroy Murdock: Did a Trump robot really delive...
# 23  Dem silence during State of the Union speech s...
# 24  Tammy Bruce: Virginia scandals show Dems aren’...
# 25  Andrew McCarthy: This investigation poses real...
# 26  US Vatican ambassador: Pope’s historic UAE vis...
# 27  Ex-Navy SEAL Jocko Willink: Remembering Michae...
# 28  Hey, Democrats, I've lived in a socialist coun...
# 29  I went through a long, dark time. I prayed God...
#
#                                                   url
# 0   /opinion/democrats-allowing-ilhan-omars-anti-s...
# 1   /opinion/new-yorks-late-term-abortion-law-is-a...
# 2   /opinion/democrats-overreach-again-in-attackin...
# 3   /opinion/have-american-universities-become-bre...
# 4   /opinion/democrats-are-having-an-identity-melt...
# 5   /opinion/trumps-sanity-highlighted-by-democrat...
# 6   /opinion/liz-peek-gops-2020-campaign-will-put-...
# 7   /opinion/steve-hilton-the-democratic-racism-sc...
# 8   /opinion/2020-election-this-is-the-democrat-tr...
# 9   /opinion/im-a-corporate-coach-heres-how-we-can...
# 10  /opinion/worst-media-moments-of-the-week-press...
# 11  /opinion/border-crisis-america-heres-an-abbrev...
# 12  /opinion/what-do-king-tuts-tomb-and-the-21st-c...
# 13  /opinion/judge-jeanine-pirro-think-socialism-c...
# 14  /opinion/grammys-2019-why-god-will-be-center-s...
# 15  /opinion/tomi-lahren-the-democratic-party-is-a...
# 16  /opinion/if-churches-want-to-get-millennials-t...
# 17  /opinion/america-should-hit-iran-where-it-hurt...
# 18  /opinion/pastor-for-me-immigration-is-biblical...
# 19  /opinion/the-most-important-thing-you-can-do-f...
# 20  /opinion/valentines-day-2019-drop-the-drama-th...
# 21  /opinion/when-i-was-born-my-parents-were-told-...
# 22  /opinion/deroy-murdock-did-a-trump-robot-reall...
# 23  /opinion/dem-silence-during-state-of-the-union...
# 24  /opinion/tammy-bruce-virginia-scandals-show-de...
# 25  /opinion/andrew-mccarthy-this-investigation-po...
# 26  /opinion/u-s-vatican-ambassador-popes-historic...
# 27  /opinion/ex-navy-seal-jocko-willink-rememberin...
# 28  /opinion/hey-democrats-ive-lived-in-a-socialis...
# 29  /opinion/i-went-through-a-long-dark-time-i-pra...

# %% [markdown]
# This does not return 100 results, but it does return 30, which appears to be the internal maximum.  Collecting a larger corpus of article metadata will need to be done in batches of 30.
#
# The next question is how far back can the API go? Here, the first suspect is the `offset` parameter. The current value of 30 is usually associated with starting with the 30th results. So an `offset` of 30 with a `size` of `10` is likely to return results 30-39.
#
# As a first pass, I set the value of `offset` to 0 to get the most recent results.

# %%
url_off = url.replace('offset=30','offset=0')

fox_df(url_off)
# Out:
# Return a dataframe of length 11
#                  category.name  \
# 0               Faith & Values
# 1                      OPINION
# 2                      OPINION
# 3                      OPINION
# 4                      OPINION
# 5                      OPINION
# 6   Laura Ingraham's Monologue
# 7   Tucker Carlson's Monologue
# 8                      OPINION
# 9                      OPINION
# 10                     OPINION
#
#                                          category.url  \
# 0                              /category/faith-values
# 1                                   /category/opinion
# 2                                   /category/opinion
# 3                                   /category/opinion
# 4                                   /category/opinion
# 5                                   /category/opinion
# 6   /category/shows/ingraham-angle/transcript/laur...
# 7   /category/shows/tucker-carlson-tonight/transcr...
# 8                                   /category/opinion
# 9                                   /category/opinion
# 10                                  /category/opinion
#
#                                           description duration  \
# 0   What is love? You won't find the best answer o...
# 1   Rep. Ilhan Omar, D-Minn., has come under justi...
# 2   California Gov. Gavin Newsom, under budgetary ...
# 3   Whew, that was a close call. But now that Demo...
# 4   To some of us, Feb. 14 is Valentine's Day. To ...
# 5   A bipartisan congressional committee has agree...
# 6   I hate to tell you I told you so, but I told y...
# 7   We have news for you, breaking news, that for ...
# 8   Trump can't win a shutdown fight today. But he...
# 9   The American Dream exists because of capitalis...
# 10  The conviction of Joaquin “El Chapo” Guzman, t...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 5   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2019-02-13T14:58:15-05:00  2019-02-13T14:58:15-05:00
# 1   2019-02-13T13:30:50-05:00  2019-02-13T13:30:50-05:00
# 2   2019-02-13T11:05:31-05:00  2019-02-13T11:05:31-05:00
# 3   2019-02-13T10:43:45-05:00  2019-02-13T10:43:45-05:00
# 4   2019-02-13T09:03:37-05:00  2019-02-13T09:03:37-05:00
# 5   2019-02-13T08:45:38-05:00  2019-02-13T08:45:38-05:00
# 6   2019-02-13T08:08:14-05:00  2019-02-13T08:08:14-05:00
# 7   2019-02-13T07:44:14-05:00  2019-02-13T07:44:14-05:00
# 8   2019-02-13T04:00:50-05:00  2019-02-13T04:00:50-05:00
# 9   2019-02-13T04:00:49-05:00  2019-02-13T04:00:49-05:00
# 10  2019-02-13T04:00:48-05:00  2019-02-13T04:00:48-05:00
#
#                                                 title  \
# 0          On Valentine's Day, 24 things that love is
# 1   Leslie Marshall: Rep. Omar's anti-Semitic twee...
# 2   California’s Gavin Newsom throws Green New Dea...
# 3   Michael Goodwin: Can the Democrats ever get ov...
# 4   Valentine’s Day chocolate – here are some not ...
# 5   Sean Hannity: How Trump can take Congress' gar...
# 6   Laura Ingraham: The border wall becomes a bord...
# 7   Tucker Carlson: There was no Russian collusion...
# 8   Marc Thiessen: Here's how Trump can get the re...
# 9   Andy Puzder: Socialism vs. Capitalism – I want...
# 10  El Chapo conviction shows power and fairness o...
#
#                                                   url
# 0   /opinion/paul-tripp-on-valentines-day-24-thing...
# 1   /opinion/rep-omars-anti-semitic-tweet-hurt-dem...
# 2   /opinion/californias-gavin-newsom-throws-green...
# 3   /opinion/michael-goodwin-can-the-democrats-eve...
# 4   /opinion/valentines-day-chocolate-here-are-som...
# 5   /opinion/sean-hannity-how-trump-can-take-congr...
# 6   /opinion/laura-ingraham-the-border-wall-become...
# 7   /opinion/tucker-carlson-there-was-no-russian-c...
# 8   /opinion/marc-thiessen-heres-how-trump-can-get...
# 9   /opinion/andy-puzder-socialism-vs-capitalism-i...
# 10  /opinion/el-chapo-conviction-shows-power-and-f...

# %% [markdown]
# The `lastPublicationDate` value of the first row is 2019-02-08. Hopefully a larger value will be associated with articles published earlier.

# %%
url_off = url.replace('offset=30','offset=100')

fox_df(url_off)
# Out:
# Return a dataframe of length 11
#    category.name       category.url  \
# 0        OPINION  /category/opinion
# 1        OPINION  /category/opinion
# 2        OPINION  /category/opinion
# 3        OPINION  /category/opinion
# 4        OPINION  /category/opinion
# 5        OPINION  /category/opinion
# 6        OPINION  /category/opinion
# 7        OPINION  /category/opinion
# 8        OPINION  /category/opinion
# 9        OPINION  /category/opinion
# 10       OPINION  /category/opinion
#
#                                           description duration  \
# 0   What is the legal status of a baby who survive...
# 1   The State of the Union speech Tuesday was a go...
# 2   “Our brave troops have now been fighting in th...
# 3   In Tuesday’s State of the Union address, Presi...
# 4   Every once in a while a speech is so effective...
# 5   I was honored to be among those Americans sele...
# 6   Democrats on the House Judiciary Committee hel...
# 7   President Donald Trump used his State of the U...
# 8   Wednesday is the 108th anniversary of the birt...
# 9   In his State of the Union speech Tuesday night...
# 10  I’ve never seen a group of Washington lawmaker...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/a57.foxnews.com/media2...       False   False
# 9   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2019-02-07T03:45:36-05:00  2019-02-07T03:45:36-05:00
# 1   2019-02-06T19:58:43-05:00  2019-02-06T19:58:43-05:00
# 2   2019-02-06T15:22:13-05:00  2019-02-06T15:22:13-05:00
# 3   2019-02-06T15:07:46-05:00  2019-02-06T15:07:46-05:00
# 4   2019-02-06T14:43:46-05:00  2019-02-06T14:43:46-05:00
# 5   2019-02-06T13:52:29-05:00  2019-02-06T13:52:29-05:00
# 6   2019-02-06T12:47:55-05:00  2019-02-06T12:47:55-05:00
# 7   2019-02-06T11:10:47-05:00  2019-02-06T11:10:47-05:00
# 8   2019-02-06T10:26:29-05:00  2019-02-06T10:26:29-05:00
# 9   2019-02-06T10:20:12-05:00  2019-02-06T10:20:12-05:00
# 10  2019-02-06T09:02:25-05:00  2019-02-06T09:02:25-05:00
#
#                                                 title  \
# 0   Judge Andrew Napolitano: Roe's little-known co...
# 1                     Gutfeld on last night’s address
# 2   Trump's right about Afghanistan and the Middle...
# 3   Trump announces another North Korea nuke summi...
# 4   Newt Gingrich: Trump's State of the Union chan...
# 5   Todd Starnes: I had a front-row seat at Trump'...
# 6   Rep. Steve Scalise: Democrats don't want you t...
# 7   Trump laid out an infrastructure strategy for ...
# 8   Ronald Reagan, born exactly 108 years ago, was...
# 9   Andy Puzder: Trump's economy has taken us from...
# 10  Dems react to Trump's economic achievements wi...
#
#                                                   url
# 0   /opinion/judge-andrew-napolitano-roes-little-k...
# 1             /opinion/gutfeld-on-last-nights-address
# 2   /opinion/trumps-right-about-afghanistan-and-th...
# 3   /opinion/trump-announces-another-north-korea-n...
# 4   /opinion/newt-gingrich-president-trumps-state-...
# 5   /opinion/todd-starnes-i-had-a-front-row-seat-a...
# 6   /opinion/rep-steve-scalise-democrats-dont-want...
# 7   /opinion/trump-laid-out-an-infrastructure-stra...
# 8   /opinion/ronald-reagan-born-exactly-108-years-...
# 9   /opinion/andy-puzder-trumps-economy-has-taken-...
# 10  /opinion/dems-react-to-trumps-economic-achieve...

# %% [markdown]
# The article with an offset value of 100 was published on 2019-02-01, or roughly a week before our offset 0. Perfect! Increasing the offset value yields additional article metadata in chronological order.
#
# Next, how far back can we go?

# %%
url_off = url.replace('offset=30','offset=1000')

fox_df(url_off)
# Out:
# Return a dataframe of length 11
#          category.name                                 category.url  \
# 0              OPINION                            /category/opinion
# 1              OPINION                            /category/opinion
# 2              OPINION                            /category/opinion
# 3              OPINION                            /category/opinion
# 4              OPINION                            /category/opinion
# 5              OPINION                            /category/opinion
# 6   Illegal Immigrants  /category/us/immigration/illegal-immigrants
# 7              OPINION                            /category/opinion
# 8              OPINION                            /category/opinion
# 9              OPINION                            /category/opinion
# 10             OPINION                            /category/opinion
#
#                                           description duration  \
# 0   A reported tentative deal between the U.S. and...
# 1   Like a basketball player who mistakenly shoots...
# 2   Former Secretary of States Condoleezza Rice wa...
# 3   What a great week to be thankful for small bus...
# 4   In one of the most provocative and misundersto...
# 5   Serving as Chairman of the House Committee on ...
# 6   President Trump was right to order troops to o...
# 7   Many journalists argue that there is no such t...
# 8   The final U.S. Senate race of 2018 is in Missi...
# 9   For someone trying to demonstrate that the jud...
# 10  As Americans pause this week to give thanks, l...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 5   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 6   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2018-11-24T21:26:10-05:00  2018-11-24T21:26:10-05:00
# 1   2018-11-24T17:25:46-05:00  2018-11-24T17:25:46-05:00
# 2   2018-11-24T12:25:33-05:00  2018-11-24T12:25:33-05:00
# 3   2018-11-24T04:00:44-05:00  2018-11-24T04:00:44-05:00
# 4   2018-11-24T04:00:36-05:00  2018-11-24T04:00:36-05:00
# 5   2018-11-24T04:00:29-05:00  2018-11-24T04:00:29-05:00
# 6   2018-11-24T04:00:04-05:00  2018-11-24T04:00:04-05:00
# 7   2018-11-24T00:00:13-05:00  2018-11-24T00:00:13-05:00
# 8   2018-11-23T20:42:27-05:00  2018-11-23T20:42:27-05:00
# 9   2018-11-23T15:17:05-05:00  2018-11-23T15:17:05-05:00
# 10  2018-11-23T10:03:42-05:00  2018-11-23T10:03:42-05:00
#
#                                                 title  \
# 0   Reported tentative migrant asylum deal with Me...
# 1   Trump is right about biased judges; Schumer ac...
# 2   Condoleezza Rice is right – NFL needs to give ...
# 3   This Small Business Saturday, let’s celebrate ...
# 4   Did a mysterious extinction event precede Adam...
# 5   Rep. Steve Chabot: This Small Business Saturda...
# 6   Trump was right to send troops to our border –...
# 7   Liberal media tell us the left is right – And ...
# 8   John Fund: Mississippi US Senate race features...
# 9   Marc Thiessen: Chief Justice Roberts is wrong....
# 10        Give thanks that ISIS is going, going . . .
#
#                                                   url
# 0   /opinion/reported-tentative-migrant-asylum-dea...
# 1   /opinion/trump-is-right-about-biased-judges-sc...
# 2   /opinion/condoleezza-rice-is-right-nfl-needs-t...
# 3   /opinion/this-small-business-saturday-lets-cel...
# 4   /opinion/did-a-mysterious-extinction-event-pre...
# 5   /opinion/rep-steve-chabot-this-small-business-...
# 6   /opinion/trump-was-right-to-send-troops-to-our...
# 7   /opinion/liberal-media-tell-us-the-left-is-rig...
# 8   /opinion/john-fund-mississippi-u-s-senate-race...
# 9   /opinion/marc-thiessen-chief-justice-roberts-i...
# 10      /opinion/give-thanks-that-isis-is-going-going

# %% [markdown]
# An offset of 1,000 takes us back about nine months.

# %%
url_off = url.replace('offset=30','offset=5000')

fox_df(url_off)
# Out:
# Return a dataframe of length 11
#         category.name                                    category.url  \
# 0            POLITICS                              /category/politics
# 1               CRIME                              /category/us/crime
# 2       MENTAL HEALTH                  /category/health/mental-health
# 3         White House        /category/politics/executive/white-house
# 4            POLITICS                              /category/politics
# 5         White House        /category/politics/executive/white-house
# 6                Iran                  /category/world/conflicts/iran
# 7   National Security  /category/politics/executive/national-security
# 8               Faith            /category/us/personal-freedoms/faith
# 9           EDUCATION                      /category/health/education
# 10             Cities       /category/politics/state-and-local/cities
#
#                                           description duration  \
# 0   Many of our country’s most cherished instituti...
# 1   The orientation for the new people takes place...
# 2   Loneliness now eclipses obesity as a cause of ...
# 3   The president ripped into the violent MS-13 ga...
# 4   God is not a racist. Torch-wielding white nati...
# 5   President Trump’s declaration Thursday that th...
# 6   Iran’s nuclear weapons activities have continu...
# 7   As the administration and the American public ...
# 8   When sabers begin to rattle around the world, ...
# 9   Over three million students were suspended for...
# 10  In Charlottesville we are watching boys playin...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 2   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 3   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 9   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2017-09-26T03:40:20-04:00  2017-08-12T07:00:00-04:00
# 1   2017-09-26T03:40:10-04:00  2017-08-12T09:30:00-04:00
# 2   2017-09-26T03:39:59-04:00  2017-08-12T06:30:00-04:00
# 3   2017-09-26T03:39:48-04:00  2017-08-12T07:15:00-04:00
# 4   2017-09-26T03:39:39-04:00  2017-08-12T11:15:00-04:00
# 5   2017-09-26T03:39:28-04:00  2017-08-12T12:00:00-04:00
# 6   2017-09-26T03:16:53-04:00  2017-08-13T15:30:00-04:00
# 7   2017-09-26T03:16:43-04:00  2017-08-13T14:30:00-04:00
# 8   2017-09-26T03:16:33-04:00  2017-08-13T13:45:00-04:00
# 9   2017-09-26T02:33:44-04:00  2017-08-14T05:00:00-04:00
# 10  2017-09-26T02:33:34-04:00  2017-08-14T15:00:00-04:00
#
#                                                 title  \
# 0   Conservatives and moderates: It's time to stop...
# 1   Becoming a prisoner in the federal prison syst...
# 2   Dr. Keith Ablow: Loneliness is now more deadly...
# 3                      Trump, the police and the spin
# 4   White Christian conservatives should oppose pr...
# 5   President Trump and other leaders must work to...
# 6   New sanctions on Iran, now it's time for a new...
# 7   Dealing with global hot spots in times of dome...
# 8   Responding to North Korea -- When sabers rattl...
# 9   Millions of kids will get suspended this year....
# 10  Erick Erickson: Charlottesville violence and t...
#
#                                                   url
# 0   /opinion/conservatives-and-moderates-its-time-...
# 1   /opinion/becoming-a-prisoner-in-the-federal-pr...
# 2   /opinion/dr-keith-ablow-loneliness-is-now-more...
# 3              /opinion/trump-the-police-and-the-spin
# 4   /opinion/white-christian-conservatives-should-...
# 5   /opinion/president-trump-and-other-leaders-mus...
# 6   /opinion/new-sanctions-on-iran-now-its-time-fo...
# 7   /opinion/dealing-with-global-hot-spots-in-time...
# 8   /opinion/responding-to-north-korea-when-sabers...
# 9   /opinion/millions-of-kids-will-get-suspended-t...
# 10  /opinion/erick-erickson-charlottesville-violen...

# %% [markdown]
# 5,000 brings us back to 2017.

# %%
url_off = url.replace('offset=30','offset=10000')

fox_df(url_off)
# Out:
# Return a dataframe of length 0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# But 10,000 fails. 😞.
#
# After attempting multiple values, it appears something around 9,950 is the maximum offset that will return results, which is approximately three years of data. This limit could be hard coded into the API or this could simply be all the data that is available on the website.

# %%
url_off = url.replace('offset=30','offset=9950')

fox_df(url_off)
# Out:
# Return a dataframe of length 11
#       category.name                               category.url  \
# 0            Family      /category/us/personal-freedoms/family
# 1      Presidential  /category/politics/elections/presidential
# 2         Democrats     /category/politics/elections/democrats
# 3         Democrats     /category/politics/elections/democrats
# 4      Persecutions      /category/world/religion/persecutions
# 5   Gretchen's Take           /category/columns/gretchens-take
# 6       Afghanistan      /category/world/conflicts/afghanistan
# 7           OPINION                          /category/opinion
# 8      Todd Starnes  /category/columns/todds-american-dispatch
# 9           Threats         /category/politics/defense/threats
# 10  Gretchen's Take           /category/columns/gretchens-take
#
#                                           description duration  \
# 0   Along with millions of viewers, I was moved to...
# 1   Donald Trump could bring a welcome pragmatism ...
# 2   What if Hillary Clinton is in legal hot water ...
# 3   The left talks a lot about poverty, but when i...
# 4   Dying Christians in the Middle East don’t need...
# 5   Will Rubio or Kasich fall on the sword to help...
# 6   Former First Lady Laura Bush tells Dana Perino...
# 7   Maybe it’s time to admit that Donadl Trump is ...
# 8   There’s a witch hunt underway for conservative...
# 9   FBI Director James Comey testified before Cong...
# 10        Some storylines seem too bizarre to be real
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/a57.foxnews.com/media2...       False   False
# 3   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 7   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 8   https://a57.foxnews.com/a57.foxnews.com/media2...       False   False
# 9   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2016-03-10T16:08:41-05:00  2016-03-10T15:52:00-05:00
# 1   2016-03-10T14:28:29-05:00  2016-03-10T14:20:00-05:00
# 2   2016-03-10T13:27:38-05:00  2016-03-10T00:00:00-05:00
# 3   2016-03-10T12:43:11-05:00  2016-03-10T12:35:00-05:00
# 4   2016-03-10T12:28:39-05:00  2016-03-10T12:09:00-05:00
# 5   2016-03-10T10:12:15-05:00  2016-03-09T10:05:00-05:00
# 6   2016-03-10T07:00:10-05:00  2016-03-10T07:00:00-05:00
# 7   2016-03-09T23:09:12-05:00  2016-03-10T01:00:00-05:00
# 8   2016-03-09T16:15:22-05:00  2016-03-09T15:52:00-05:00
# 9   2016-03-09T13:23:42-05:00  2016-03-09T12:53:00-05:00
# 10  2016-03-09T13:03:21-05:00  2016-03-08T16:03:00-05:00
#
#                                                 title  \
# 0   What Kelly Clarkson can teach us about fathers...
# 1       Why Donald Trump's foreign policy makes sense
# 2   The big question about Hillary Clinton: What i...
# 3                Bernie Sanders, white poverty and me
# 4   Mr. Obama, words matter. Call the massacre of ...
# 5          Gretchen's Take: Politics change on a dime
# 6   Former First Lady Laura Bush talks with Dana P...
# 7   Thank you, America, for playing 'Celebrity App...
# 8   Student senator faces impeachment for conserva...
# 9   Chairman McCaul: The terrorist exodus has begu...
# 10  Gretchen's Take: 2016 election playing out lik...
#
#                                                   url
# 0   /opinion/what-kelly-clarkson-can-teach-us-abou...
# 1   /opinion/why-donald-trumps-foreign-policy-make...
# 2   /opinion/the-big-question-about-hillary-clinto...
# 3        /opinion/bernie-sanders-white-poverty-and-me
# 4   /opinion/mr-obama-words-matter-call-the-massac...
# 5   /opinion/gretchens-take-politics-change-on-a-dime
# 6   /opinion/former-first-lady-laura-bush-talks-wi...
# 7   /opinion/thank-you-america-for-playing-celebri...
# 8   /opinion/student-senator-faces-impeachment-for...
# 9   /opinion/chairman-mccaul-the-terrorist-exodus-...
# 10  /opinion/gretchens-take-2016-election-playing-...

# %% [markdown]
# The final step in collecting the article metadata via the API is to make all the necessary API calls to gather all the relevant article metadata. I slightly revise the `fox_df` function so that it takes a value of an offset. I hardcoded the URL, fixing the size to 30.  A more robust function would turn the entire set of parameters into a dictionary that was modifiable. I also took out the print statement which would clutter the results.

# %%
def fox_df(offset):
    url = ('https://www.foxnews.com/api/article-search?'
           'isCategory=true&isTag=false&isKeyword=false&'
           'isFixed=false&isFeedUrl=false&searchSelected=opinion&'
           'contentTypes=%7B%22interactive%22:true,%22slideshow%22:true,%22video%22:false,%22article%22:true%7D&'
           'size=30&offset=0')
    
    url = url.replace('offset=0', 'offset=%s' % offset)
    
    r = requests.get(url)
    df = json_normalize(r.json())
    return df

# %% [markdown]
# Finally, I loop over the function. I create an empty dataframe and then append the results after each loop. I pause three seconds each pass in order to not access the web server too many times. The first time I ran this, I only retrieved a few pages of results to make sure everything worked.

# %%
from time import sleep # for pausing

# create empty dataframe to store results
fox_opinion_df = pd.DataFrame() 

# Create a loop that counts up by 30.
for offset in range(0, 1000, 30):
    new_df = fox_df(offset)
    
    # Add the new results to the existing database
    fox_opinion_df = fox_opinion_df.append(new_df, ignore_index=True)
    
    # Pause for three seconds to be polite to the web server
    sleep(3)

# %%
fox_opinion_df.tail()
# Out:
#      category.name              category.url  \
# 1015       OPINION         /category/opinion
# 1016       OPINION         /category/opinion
# 1017      THE FIVE  /category/shows/the-five
# 1018       OPINION         /category/opinion
# 1019       OPINION         /category/opinion
#
#                                             description duration  \
# 1015  Congress and the president must find a way to ...
# 1016  It’s the quintessential irony of the American ...
# 1017  Why do the media freak out whenever President ...
# 1018  It has pleased Almighty God to prolong our nat...
# 1019  Thanksgiving for me is about the Big Fs – fami...
#
#                                                imageUrl  isBreaking  isLive  \
# 1015  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1016  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1017  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1018  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1019  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
#
#               lastPublishedDate            publicationDate  \
# 1015  2018-11-23T04:00:26-05:00  2018-11-23T04:00:26-05:00
# 1016  2018-11-23T04:00:20-05:00  2018-11-23T04:00:20-05:00
# 1017  2018-11-22T12:44:01-05:00  2018-11-21T18:43:17-05:00
# 1018  2018-11-22T04:00:58-05:00  2018-11-22T04:00:58-05:00
# 1019  2018-11-22T04:00:47-05:00  2018-11-22T04:00:47-05:00
#
#                                                   title  \
# 1015  Social Security, Medicare and Medicaid spendin...
# 1016  This Black Friday beware of living with full c...
# 1017           Gutfeld on Trump's response to Khashoggi
# 1018    Abraham Lincoln's Thanksgiving Day Proclamation
# 1019  Five things I learned from Thanksgiving family...
#
#                                                     url
# 1015  /opinion/social-security-medicare-and-medicaid...
# 1016  /opinion/this-black-friday-beware-of-living-wi...
# 1017   /opinion/gutfeld-on-trumps-response-to-khashoggi
# 1018  /opinion/abraham-lincolns-thanksgiving-day-pro...
# 1019  /opinion/five-things-i-learned-from-thanksgivi...

# %% [markdown]
# The dataframe can be stored as either as CSV file or JSON. CSV is best if you want to use it elsewhere, while a JSON usually is more robust to handling text strings which somtimes trip up CSV readers.

# %%
fox_opinion_df.to_csv('foxnews_opinion.csv')

# %%
fox_opinion_df.to_json('foxnews_opinion.json', orient ='records')

# %% [markdown]
# Things aren't always this easy, but when you stumble across an undocumented API you can quickly put together a dataset.
