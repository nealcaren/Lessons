# %% [markdown]
# ## Undocument APIs

# %% [markdown]
# Social scientists are often interested in collecting massive amounts of digital data from specific websites. When you are fortunate, someone else has already scrapped it for you and has released in on [GitHub](https://github.com) or as a [Kaggle dataset](https://www.kaggle.com/datasets). Sometimes the website provides an [API](https://en.wikipedia.org/wiki/Web_API), an interface for collecting the data in a systematic way that is usually reasonably well-document. The most prominent of these for social scientists is probably [Twitter](https://developer.twitter.com/en/docs.html), who have enabled hundreds of academic studies by making available information about posts and users.
#
# Other times, an API exists and is being used by the website, but information about is not publicly available. Most website searches, for example, involve using an internal web API. Your search term, along with other relevant parameters, is used to extract the corresponding results from a dataset and then displayed on a web page. While we see the data as part of a web page, the data is often transmitted in a different, more research-friend format, usually in a [JSON](https://en.wikipedia.org/wiki/JSON) format. Using an undocumented API allows you to systematically collect the data without the parsing the HTML of each page.
#
# Below, I walk through the steps I recently used  when trying to gather Fox News Opinion articles. In this case, the API doesn't return the full text of the articles, but, as is often the case, returns all the metadata about the article, including the article URL for subsequent scraping.
#
# I use Python, but the overall logic is similar for other languages.

# %% [markdown]
# I begin by enabling the developer toolbar on my browser. In Safari, this is under **Preferences->Advanced** and then clicking **Show Develop Menu in Menu Bar**. The process is similar in Chrome.

# %% [markdown]
# I visited the front page.
# ![frontpage](images/frontpage.png)

# %% [markdown]
# I clicked on **Opinion**, the section I wanted to scrape.
# ![opinion](images/opinion.png)

# %% [markdown]
# I scrolled down the page and found a list of articles with a **Show More** button. This type of button, which leads to the next set of results, is a key component for understanding how the webpage is structured.
# ![more.png](images/more.png)

# %% [markdown]
# In this case, **Show More** does not load a new page but it does expand the number of results shown on the existing page. If you copy the link associated with this button (`https://www.foxnews.com/opinion#`) and paste it in a new browser window, it merely displays the first set of results, so that is a dead end for uncovering an API.
#
# To be confident that there might be a decent number of articles available, I clicked the **Show More** button several times. Each time it loaded more articles.
# ![more.png](images/more2.png)

# %% [markdown]
# Lots of data is passed between my computer and the Foxnews website with each click. Additional information about these streams can be revealed through the **Develop** menu and then the **Show Page Resources** option.
#
# ![develop.png](images/develop.png)

# %% [markdown]
# This defaults to showing the page's HTML code.
# ![html.png](images\html.png)

# %% [markdown]
# To look for signs of an API, I click on the **Network** tab. Results are sometimes already listed, but I start clean by using the trash icon on the far right. With the **Network** tab visible, I then click **Show More** on the web page. Each resource exchanged between my computer and various servers are now displayed. When the action stops, I sort the list by size.
# ![network.png](images\network1.png)

# %% [markdown]
# I now review each of the items for something that looks like the results of search API, a plain text file with the search results.
#
# Usually, the top of the list displays the images that the page retrieved. Images usually have a .png or .jpg extension. Selecting the first item in the results, an JPG with a name full of numbers, confirms that it is a picture.
#
# ![image.png](images\network_image.png)

# %% [markdown]
# The name of the second item, **article-search** has more promise. The **Preview** tab shows that this is a JSON object that appears to be a list of the articles that were returned after the **Show More** button was pressed. Bingo!
#
# ![image.png](images\network_search.png)

# %% [markdown]
# The **Header** tab reveals the specific URL that returned this JSON.
# ![image.png](images\network_header.png)

# %% [markdown]
# The URL has all the signs of an undocumented API. First, it contains "API" as part of the string. Second, it includes a series of search parameters, such as `isCategory` and `size`.  Now I copy the URL and paste and save it as a Python string. I split the string over several lines to view it more clearly.

# %%
url = ('https://www.foxnews.com/api/article-search?'
       'isCategory=true&isTag=false&isKeyword=false&'
       'isFixed=false&isFeedUrl=false&searchSelected=opinion&'
       'contentTypes=%7B%22interactive%22:true,%22slideshow%22:true,%22video%22:false,%22article%22:true%7D&'
       'size=11&offset=30')

# %% [markdown]
# The next step is to see if Python can access the API with a straightforward command. Some APIs require confirmation that the search is originating from original websites, while others do not enforce that. Figuring out the right way to programmatically access the website is a process of trial and error. I use the `requests` library.

# %%
import requests

r = requests.get(url)
r.status_code
# Out:
# 200

# %% [markdown]
# A status code of 200 means that something was returned.
#
# Since it looked like a JSON object when viewed in the browser, I take advantage of the `requests` JSON decoder.

# %%
r.json()
# Out:
# [{'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'The State of the Union speech Tuesday was a good night for President Trump, a bad one for the media. In tone and tenor, Trump nailed much of it – like his uncompromising rejection of socialism.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999360740001_5999357801001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T19:58:43-05:00',
#   'publicationDate': '2019-02-06T19:58:43-05:00',
#   'title': 'Gutfeld on last night’s address',
#   'url': '/opinion/gutfeld-on-last-nights-address'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': '“Our brave troops have now been fighting in the Middle East for almost 19 years,” President Trump said in his State of the Union address Tuesday night. “Great nations do not fight endless wars.”',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999037741001_5999037653001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T15:22:13-05:00',
#   'publicationDate': '2019-02-06T15:22:13-05:00',
#   'title': "Trump's right about Afghanistan and the Middle East – 'Everybody’s tired' of America's endless wars",
#   'url': '/opinion/trumps-right-about-afghanistan-and-the-middle-east-everybodys-tired-of-americas-endless-wars'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'In Tuesday’s State of the Union address, President Trump announced he will hold a second nuclear summit with North Korean leader Kim Jong Un in Vietnam Feb. 27 and 28. But Trump gave no clues as to how this new round of talks will move the denuclearization ball forward in the face of a recalcitrant North Korea.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999010594001_5999013058001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T15:07:46-05:00',
#   'publicationDate': '2019-02-06T15:07:46-05:00',
#   'title': "Trump announces another North Korea nuke summit – Here's the big mistake he should now avoid",
#   'url': '/opinion/trump-announces-another-north-korea-nuke-summit-heres-the-big-mistake-he-should-now-avoid'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'Every once in a while a speech is so effective and powerful it changes the trajectory of history. President Trump’s 2019 State of the Union address was that kind of speech.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999010594001_5999013058001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T14:43:46-05:00',
#   'publicationDate': '2019-02-06T14:43:46-05:00',
#   'title': "Newt Gingrich: Trump's State of the Union changed history on Tuesday night – Here's what Pelosi must've felt",
#   'url': '/opinion/newt-gingrich-president-trumps-state-of-the-union-changed-history'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'I was honored to be among those Americans selected to sit in the House gallery at the State of the Union address Tuesday night.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5998958676001_5998957493001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T13:52:29-05:00',
#   'publicationDate': '2019-02-06T13:52:29-05:00',
#   'title': "Todd Starnes: I had a front-row seat at Trump's State of the Union -- You won't believe what I saw",
#   'url': '/opinion/todd-starnes-i-had-a-front-row-seat-at-trumps-state-of-the-union-you-wont-believe-what-i-saw'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': "Democrats on the House Judiciary Committee held a hearing Wednesday on new gun control legislation Democrats plan to push on the American people. Democrats would not allow me to speak. Here's the testimony I planned to give.",
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999200848001_5999195873001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T12:47:55-05:00',
#   'publicationDate': '2019-02-06T12:47:55-05:00',
#   'title': "Rep. Steve Scalise: Democrats don't want you to hear what I have to say about guns and the Second Amendment",
#   'url': '/opinion/rep-steve-scalise-democrats-dont-want-you-to-hear-what-i-have-to-say-about-guns-and-the-second-amendment'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'President Donald Trump used his State of the Union address to focus the nation on policies which can unite rather than divide us.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999178267001_5999183686001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T11:10:47-05:00',
#   'publicationDate': '2019-02-06T11:10:47-05:00',
#   'title': "Trump laid out an infrastructure strategy for growth – Let's get moving and unite around it",
#   'url': '/opinion/trump-laid-out-an-infrastructure-strategy-for-growth-lets-get-moving-and-unite-around-it'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'Wednesday is the 108th anniversary of the birth of one of our greatest presidents – Ronald Reagan. And as we saw in the Super Bowl Sunday, “Reagan” still means “right.”',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/a57.foxnews.com/media2.foxnews.com/2016/09/26/640/360/348/196/092616_reagan_life_1280.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T10:26:29-05:00',
#   'publicationDate': '2019-02-06T10:26:29-05:00',
#   'title': 'Ronald Reagan, born exactly 108 years ago, was right in so many ways – Just ask Tom Brady',
#   'url': '/opinion/ronald-reagan-born-exactly-108-years-ago-was-right-in-so-many-ways-ask-tom-brady'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'In his State of the Union speech Tuesday night, President Trump talked about the strong economic and jobs growth in the U.S. under his administration. While this success story gets far less attention than it deserves, it has benefitted all Americans.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999088779001_5999090557001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T10:20:12-05:00',
#   'publicationDate': '2019-02-06T10:20:12-05:00',
#   'title': "Andy Puzder: Trump's economy has taken us from stagnation to boom -- That's a story that needs to be told",
#   'url': '/opinion/andy-puzder-trumps-economy-has-taken-us-from-stagnation-to-boom-thats-a-story-that-needs-to-be-told'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': "I’ve never seen a group of Washington lawmakers visibly upset to hear that America is back at work. But that's exactly what I saw from Democrats at last night's State of the Union.",
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999010594001_5999013058001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T09:02:25-05:00',
#   'publicationDate': '2019-02-06T09:02:25-05:00',
#   'title': "Dems react to Trump's economic achievements with stone faces and eye rolls – Will they ever grow up?",
#   'url': '/opinion/dems-react-to-trumps-economic-achievements-with-stone-faces-and-eye-rolls-will-they-ever-grow-up'},
#  {'category': {'name': 'OPINION', 'url': '/category/opinion'},
#   'description': 'The anti-Trump media greeted the president’s speech with snark, sarcasm and outright opposition.',
#   'duration': '',
#   'imageUrl': 'https://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2019/02/06/348/196/694940094001_5999037741001_5999037653001-vs.jpg?ve=1&tl=1',
#   'isBreaking': False,
#   'isLive': False,
#   'lastPublishedDate': '2019-02-06T07:40:24-05:00',
#   'publicationDate': '2019-02-06T01:47:51-05:00',
#   'title': "CNN's Van Jones calls Trump speech 'cookies and dog poop'— Press doles out snark, sarcasm and opposition",
#   'url': '/opinion/cnns-van-jones-calls-trump-speech-cookies-and-dog-poop-press-doles-out-snark-sarcasm-and-opposition'}]

# %% [markdown]
# The best way to turn a JSON into usable a format is with the `pandas` library.

# %%
import pandas as pd

df = pd.DataFrame(r.json())

# %%
df.head()
# Out:
#                                           category  \
# 0  {'name': 'OPINION', 'url': '/category/opinion'}
# 1  {'name': 'OPINION', 'url': '/category/opinion'}
# 2  {'name': 'OPINION', 'url': '/category/opinion'}
# 3  {'name': 'OPINION', 'url': '/category/opinion'}
# 4  {'name': 'OPINION', 'url': '/category/opinion'}
#
#                                          description duration  \
# 0  The State of the Union speech Tuesday was a go...
# 1  “Our brave troops have now been fighting in th...
# 2  In Tuesday’s State of the Union address, Presi...
# 3  Every once in a while a speech is so effective...
# 4  I was honored to be among those Americans sele...
#
#                                             imageUrl  isBreaking  isLive  \
# 0  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#            lastPublishedDate            publicationDate  \
# 0  2019-02-06T19:58:43-05:00  2019-02-06T19:58:43-05:00
# 1  2019-02-06T15:22:13-05:00  2019-02-06T15:22:13-05:00
# 2  2019-02-06T15:07:46-05:00  2019-02-06T15:07:46-05:00
# 3  2019-02-06T14:43:46-05:00  2019-02-06T14:43:46-05:00
# 4  2019-02-06T13:52:29-05:00  2019-02-06T13:52:29-05:00
#
#                                                title  \
# 0                    Gutfeld on last night’s address
# 1  Trump's right about Afghanistan and the Middle...
# 2  Trump announces another North Korea nuke summi...
# 3  Newt Gingrich: Trump's State of the Union chan...
# 4  Todd Starnes: I had a front-row seat at Trump'...
#
#                                                  url
# 0            /opinion/gutfeld-on-last-nights-address
# 1  /opinion/trumps-right-about-afghanistan-and-th...
# 2  /opinion/trump-announces-another-north-korea-n...
# 3  /opinion/newt-gingrich-president-trumps-state-...
# 4  /opinion/todd-starnes-i-had-a-front-row-seat-a...

# %% [markdown]
# That looks pretty good. The JSON appears to have some nested elements in it. For example, Category contains a dictionary. These can often be flattened with `json_normalize`.

# %%
from pandas.io.json import json_normalize

df = json_normalize(r.json())

df.head()
# Out:
#   category.name       category.url  \
# 0       OPINION  /category/opinion
# 1       OPINION  /category/opinion
# 2       OPINION  /category/opinion
# 3       OPINION  /category/opinion
# 4       OPINION  /category/opinion
#
#                                          description duration  \
# 0  The State of the Union speech Tuesday was a go...
# 1  “Our brave troops have now been fighting in th...
# 2  In Tuesday’s State of the Union address, Presi...
# 3  Every once in a while a speech is so effective...
# 4  I was honored to be among those Americans sele...
#
#                                             imageUrl  isBreaking  isLive  \
# 0  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#            lastPublishedDate            publicationDate  \
# 0  2019-02-06T19:58:43-05:00  2019-02-06T19:58:43-05:00
# 1  2019-02-06T15:22:13-05:00  2019-02-06T15:22:13-05:00
# 2  2019-02-06T15:07:46-05:00  2019-02-06T15:07:46-05:00
# 3  2019-02-06T14:43:46-05:00  2019-02-06T14:43:46-05:00
# 4  2019-02-06T13:52:29-05:00  2019-02-06T13:52:29-05:00
#
#                                                title  \
# 0                    Gutfeld on last night’s address
# 1  Trump's right about Afghanistan and the Middle...
# 2  Trump announces another North Korea nuke summi...
# 3  Newt Gingrich: Trump's State of the Union chan...
# 4  Todd Starnes: I had a front-row seat at Trump'...
#
#                                                  url
# 0            /opinion/gutfeld-on-last-nights-address
# 1  /opinion/trumps-right-about-afghanistan-and-th...
# 2  /opinion/trump-announces-another-north-korea-n...
# 3  /opinion/newt-gingrich-president-trumps-state-...
# 4  /opinion/todd-starnes-i-had-a-front-row-seat-a...

# %% [markdown]
# Great! This process demonstrates that FoxNews has an undocumented API that can be accessed via Python. The dataset, however, only has a few cases.

# %%
len(df)
# Out:
# 11

# %% [markdown]
# The next step is to see if more data can be collected. I usually focus on two parameters: How do I get to the next set of results? Can I get more results with each call?

# %%
print(url)
# Out:
# https://www.foxnews.com/api/article-search?isCategory=true&isTag=false&isKeyword=false&isFixed=false&isFeedUrl=false&searchSelected=opinion&contentTypes=%7B%22interactive%22:true,%22slideshow%22:true,%22video%22:false,%22article%22:true%7D&size=11&offset=30

# %% [markdown]
# Looking back at the URL, the likely suspects for manipulation are `size`, which usually determines the number of results, and `offset` which usually means "start with the nth result". I first check to see how many results can be returned in one call. If the answer is 10,000, I don't need to do much more.
#
# Since I'll be making many calls using the API, I write a quick function to take the URL and return a dataframe. Once I'm confident it will work, I would likely make a more robust function that allows more direct manipulation of the parameters, but I don't want to spend too much time on that if the whole API is a dead end.

# %%
def fox_df(url):
    r = requests.get(url)
    df = json_normalize(r.json())
    print('Return a dataframe of length',len(df))
    return df

# %% [markdown]
# I confirm that the function works using the original url.

# %%
fox_df(url)
# Out:
# Return a df of length 11
#                                            category  \
# 0   {'name': 'OPINION', 'url': '/category/opinion'}
# 1   {'name': 'OPINION', 'url': '/category/opinion'}
# 2   {'name': 'OPINION', 'url': '/category/opinion'}
# 3   {'name': 'OPINION', 'url': '/category/opinion'}
# 4   {'name': 'OPINION', 'url': '/category/opinion'}
# 5   {'name': 'OPINION', 'url': '/category/opinion'}
# 6   {'name': 'OPINION', 'url': '/category/opinion'}
# 7   {'name': 'OPINION', 'url': '/category/opinion'}
# 8   {'name': 'OPINION', 'url': '/category/opinion'}
# 9   {'name': 'OPINION', 'url': '/category/opinion'}
# 10  {'name': 'OPINION', 'url': '/category/opinion'}
#
#                                           description duration  \
# 0   The State of the Union speech Tuesday was a go...
# 1   “Our brave troops have now been fighting in th...
# 2   In Tuesday’s State of the Union address, Presi...
# 3   Every once in a while a speech is so effective...
# 4   I was honored to be among those Americans sele...
# 5   Democrats on the House Judiciary Committee hel...
# 6   President Donald Trump used his State of the U...
# 7   Wednesday is the 108th anniversary of the birt...
# 8   In his State of the Union speech Tuesday night...
# 9   I’ve never seen a group of Washington lawmaker...
# 10  The anti-Trump media greeted the president’s s...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/a57.foxnews.com/media2...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2019-02-06T19:58:43-05:00  2019-02-06T19:58:43-05:00
# 1   2019-02-06T15:22:13-05:00  2019-02-06T15:22:13-05:00
# 2   2019-02-06T15:07:46-05:00  2019-02-06T15:07:46-05:00
# 3   2019-02-06T14:43:46-05:00  2019-02-06T14:43:46-05:00
# 4   2019-02-06T13:52:29-05:00  2019-02-06T13:52:29-05:00
# 5   2019-02-06T12:47:55-05:00  2019-02-06T12:47:55-05:00
# 6   2019-02-06T11:10:47-05:00  2019-02-06T11:10:47-05:00
# 7   2019-02-06T10:26:29-05:00  2019-02-06T10:26:29-05:00
# 8   2019-02-06T10:20:12-05:00  2019-02-06T10:20:12-05:00
# 9   2019-02-06T09:02:25-05:00  2019-02-06T09:02:25-05:00
# 10  2019-02-06T07:40:24-05:00  2019-02-06T01:47:51-05:00
#
#                                                 title  \
# 0                     Gutfeld on last night’s address
# 1   Trump's right about Afghanistan and the Middle...
# 2   Trump announces another North Korea nuke summi...
# 3   Newt Gingrich: Trump's State of the Union chan...
# 4   Todd Starnes: I had a front-row seat at Trump'...
# 5   Rep. Steve Scalise: Democrats don't want you t...
# 6   Trump laid out an infrastructure strategy for ...
# 7   Ronald Reagan, born exactly 108 years ago, was...
# 8   Andy Puzder: Trump's economy has taken us from...
# 9   Dems react to Trump's economic achievements wi...
# 10  CNN's Van Jones calls Trump speech 'cookies an...
#
#                                                   url
# 0             /opinion/gutfeld-on-last-nights-address
# 1   /opinion/trumps-right-about-afghanistan-and-th...
# 2   /opinion/trump-announces-another-north-korea-n...
# 3   /opinion/newt-gingrich-president-trumps-state-...
# 4   /opinion/todd-starnes-i-had-a-front-row-seat-a...
# 5   /opinion/rep-steve-scalise-democrats-dont-want...
# 6   /opinion/trump-laid-out-an-infrastructure-stra...
# 7   /opinion/ronald-reagan-born-exactly-108-years-...
# 8   /opinion/andy-puzder-trumps-economy-has-taken-...
# 9   /opinion/dems-react-to-trumps-economic-achieve...
# 10  /opinion/cnns-van-jones-calls-trump-speech-coo...

# %% [markdown]
# As a first attempt, I try to retrieve 100 results.

# %%
url100 = url.replace('size=11','size=100')

fox_df(url100)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-74-0bc17a55885b> in <module>()
#       1 url100 = url.replace('size=11','size=100')
#       2
# ----> 3 fox_df(url100)
#
# <ipython-input-63-c6f42f652a2f> in fox_df(offset)
#       9
#      10     r = requests.get(url)
# ---> 11     df = json_normalize(r.json())
#      12     return df
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# This does not return 100 results, but it does return 30, which appears to be the internal maximum.  Collecting a larger corpus of article metadata will need to be done in batches of 30.
#
# The next question is how far back can the API go? Here, the first suspect is the `offset` parameter. The current value of 30 is usually associated with starting with the 30th results. So an `offset` of 30 with a `size` of `10` is likely to return results 30-39.
#
# As a first pass, I set the value of `offset` to 0 to get the most recent results.

# %%
url_off = url.replace('offset=30','offset=0')

fox_df(url_off)
# Out:
# Return a df of length 11
#                                              category  \
# 0     {'name': 'OPINION', 'url': '/category/opinion'}
# 1   {'name': 'Abortion', 'url': '/category/politic...
# 2     {'name': 'OPINION', 'url': '/category/opinion'}
# 3     {'name': 'OPINION', 'url': '/category/opinion'}
# 4     {'name': 'OPINION', 'url': '/category/opinion'}
# 5   {'name': 'Laura Ingraham's Monologue', 'url': ...
# 6   {'name': 'Tucker Carlson's Monologue', 'url': ...
# 7     {'name': 'OPINION', 'url': '/category/opinion'}
# 8     {'name': 'OPINION', 'url': '/category/opinion'}
# 9     {'name': 'OPINION', 'url': '/category/opinion'}
# 10    {'name': 'OPINION', 'url': '/category/opinion'}
#
#                                           description duration  \
# 0   In their thirst to bloody or defeat Kavanaugh ...
# 1   With late-term abortions – those performed aft...
# 2   This plan is really a nifty piece of marketing...
# 3   As the 116th Congress begins, service has neve...
# 4   Alexandria Ocasio-Cortez has a megaphone that ...
# 5   Laura Ingraham: We can let the PC Puritans sca...
# 6   Tucker Carlson: We shouldn't be surprised that...
# 7   "Great nations do not fight endless wars," Pre...
# 8   Billionaires are not a problem. The rich creat...
# 9   The 'Green New Deal' is a radical and impracti...
# 10  On Thursday, President Trump signed a presiden...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 10  https://a57.foxnews.com/media.foxbusiness.com/...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2019-02-08T11:32:37-05:00  2019-02-08T11:32:37-05:00
# 1   2019-02-08T11:23:00-05:00  2019-02-08T11:23:00-05:00
# 2   2019-02-08T09:53:31-05:00  2019-02-08T09:53:31-05:00
# 3   2019-02-08T07:47:51-05:00  2019-02-08T07:47:51-05:00
# 4   2019-02-08T07:14:01-05:00  2019-02-08T07:14:01-05:00
# 5   2019-02-08T07:04:49-05:00  2019-02-08T07:04:49-05:00
# 6   2019-02-08T06:21:15-05:00  2019-02-08T06:21:15-05:00
# 7   2019-02-08T04:00:33-05:00  2019-02-08T04:00:33-05:00
# 8   2019-02-07T19:12:00-05:00  2019-02-07T19:12:00-05:00
# 9   2019-02-07T16:22:52-05:00  2019-02-07T16:22:52-05:00
# 10  2019-02-07T15:35:07-05:00  2019-02-07T15:35:07-05:00
#
#                                                 title  \
# 0   Lessons from Kavanaugh replacement hearing – D...
# 1   Dr. Kent Ingle: ‘Pro-abortion bills’ are inhum...
# 2   Mark Penn: Green New Deal has more in common w...
# 3   Michael Knowles: Trump and those self-obsessed...
# 4   Kimberley Strassel: Alexandria Ocasio-Cortez -...
# 5   Laura Ingraham: We must be careful not to bow ...
# 6   Tucker Carlson: Wearing blackface is fairly co...
# 7   Marc Thiessen: Yes, it feels like there are 'e...
# 8                  Gutfeld on abolishing billionaires
# 9   Democrats' 'Green New Deal' is a Crazy New Dea...
# 10  The Women’s Global Development and Prosperity ...
#
#                                                   url
# 0   /opinion/lessons-from-kavanaugh-replacement-he...
# 1   /opinion/dr-kent-ingle-pro-abortion-bills-acro...
# 2   /opinion/mark-penn-green-new-deal-has-more-in-...
# 3   /opinion/michael-knowles-trump-and-those-self-...
# 4   /opinion/kimberley-strassel-alexandria-ocasio-...
# 5   /opinion/laura-ingraham-we-must-be-careful-not...
# 6   /opinion/tucker-carlson-wearing-blackface-is-f...
# 7   /opinion/marc-thiessen-yes-it-feels-like-there...
# 8         /opinion/gutfeld-on-abolishing-billionaires
# 9   /opinion/democrats-green-new-deal-is-a-crazy-n...
# 10  /opinion/the-womens-global-development-and-pro...

# %% [markdown]
# The `lastPublicationDate` value of the first row is 2019-02-08. Hopefully a larger value will be associated with articles published earlier.

# %%
url_off = url.replace('offset=30','offset=100')

fox_df(url_off)
# Out:
# Return a df of length 11
#                                              category  \
# 0   {'name': 'Government Shutdown', 'url': '/categ...
# 1   {'name': 'Abortion', 'url': '/category/politic...
# 2   {'name': 'Fox Nation', 'url': '/category/fox-n...
# 3     {'name': 'OPINION', 'url': '/category/opinion'}
# 4     {'name': 'OPINION', 'url': '/category/opinion'}
# 5     {'name': 'OPINION', 'url': '/category/opinion'}
# 6   {'name': 'Sean Hannity's Monologue', 'url': '/...
# 7     {'name': 'OPINION', 'url': '/category/opinion'}
# 8   {'name': 'Tucker Carlson's Monologue', 'url': ...
# 9     {'name': 'OPINION', 'url': '/category/opinion'}
# 10    {'name': 'OPINION', 'url': '/category/opinion'}
#
#                                           description duration  \
# 0   We can’t continue to find ourselves in complet...
# 1   Politicians advocating for late-term abortion ...
# 2   Roger Stone was arrested in a pre-dawn raid at...
# 3   I am not willing to count out the 41-year-old ...
# 4   There is not a single reason to believe that i...
# 5   Pro-life Americans have been staggered by the ...
# 6   As we watch the extreme radical left, it's rea...
# 7   Senate opposes Trump's plan to withdraw U.S. f...
# 8   Polar vortex reminds us that energy matters - ...
# 9   For the players in Sunday’s game, success mean...
# 10  Instead of debating Republicans, Democrats may...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 3   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2019-02-01T18:11:41-05:00  2019-02-01T18:11:41-05:00
# 1   2019-02-01T17:46:08-05:00  2019-02-01T17:46:08-05:00
# 2   2019-02-01T17:31:27-05:00  2019-02-01T17:31:27-05:00
# 3   2019-02-01T16:52:00-05:00  2019-02-01T16:52:00-05:00
# 4   2019-02-01T12:32:04-05:00  2019-02-01T12:32:04-05:00
# 5   2019-02-01T11:41:38-05:00  2019-02-01T11:41:38-05:00
# 6   2019-02-01T07:08:19-05:00  2019-02-01T07:08:19-05:00
# 7   2019-02-01T06:53:51-05:00  2019-02-01T04:00:56-05:00
# 8   2019-02-01T06:40:06-05:00  2019-02-01T06:40:06-05:00
# 9   2019-02-01T04:00:45-05:00  2019-02-01T04:00:45-05:00
# 10  2019-02-01T04:00:11-05:00  2019-02-01T04:00:11-05:00
#
#                                                 title  \
# 0   Rep. Rob Wittman:  Shutdowns really ARE avoida...
# 1   Dr. Manny Alvarez: Late term abortion in New Y...
# 2   Judge Andrew Napolitano: The Roger Stone arres...
# 3   Dr. Marc Siegel: Tom Brady's ability to put mi...
# 4   Venezuela is the socialist-wasteland that Ocas...
# 5   Todd Starnes: Why the heck is Facebook blockin...
# 6   Sean Hannity: Radical leftist Dems want more g...
# 7   Trump shouldn't pull out of Syria right now – ...
# 8   Tucker Carlson: Dems pushing the Green New Dea...
# 9   Dear God, is it OK for me to pray that my team...
# 10  Marc Thiessen: THIS is the person who would do...
#
#                                                   url
# 0   /opinion/rep-rob-wittman-shutdowns-really-are-...
# 1   /opinion/dr-manny-alvarez-late-term-abortion-i...
# 2   /opinion/judge-andrew-napolitano-the-roger-sto...
# 3   /opinion/dr-marc-siegel-tom-bradys-ability-to-...
# 4   /opinion/venezuela-is-the-socialist-wasteland-...
# 5   /opinion/todd-starnes-why-the-heck-is-facebook...
# 6   /opinion/sean-hannity-radical-leftist-dems-wan...
# 7   /opinion/trump-shouldnt-pull-out-of-syria-righ...
# 8   /opinion/tucker-carlson-dems-pushing-the-green...
# 9   /opinion/dear-god-is-it-ok-for-me-to-pray-that...
# 10  /opinion/marc-thiessen-this-is-the-person-who-...

# %% [markdown]
# The article with an offset value of 100 was published on 2019-02-01, or roughly a week before our offset 0. Perfect! Increasing the offset value yields additional article metadata in chronological order.
#
# Next, how far back can we go?

# %%
url_off = url.replace('offset=30','offset=1000')

fox_df(url_off)
# Out:
# Return a df of length 11
#                                              category  \
# 0     {'name': 'OPINION', 'url': '/category/opinion'}
# 1     {'name': 'OPINION', 'url': '/category/opinion'}
# 2     {'name': 'OPINION', 'url': '/category/opinion'}
# 3   {'name': 'Faith', 'url': '/category/us/persona...
# 4     {'name': 'OPINION', 'url': '/category/opinion'}
# 5     {'name': 'OPINION', 'url': '/category/opinion'}
# 6     {'name': 'OPINION', 'url': '/category/opinion'}
# 7     {'name': 'OPINION', 'url': '/category/opinion'}
# 8     {'name': 'OPINION', 'url': '/category/opinion'}
# 9     {'name': 'OPINION', 'url': '/category/opinion'}
# 10    {'name': 'OPINION', 'url': '/category/opinion'}
#
#                                           description duration  \
# 0   It’s almost Thanksgiving, so we could give tha...
# 1   Enactment of the First Step Act would represen...
# 2   I hate Thanksgiving and I suspect that I’m not...
# 3   Nicholas was a man of God who worked tirelessl...
# 4   With Thanksgiving right around the corner, I m...
# 5   Well, it’s official. Over the past 14 months, ...
# 6   I felt sure there had to be some sort of awful...
# 7   A new North Korean weapons test could lead to ...
# 8   One of the key lessons of last week’s midterm ...
# 9   Right now, thousands of Central American migra...
# 10  Millions of us have complained for years about...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 3   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 9   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2018-11-17T04:00:58-05:00  2018-11-17T04:00:58-05:00
# 1   2018-11-17T04:00:37-05:00  2018-11-17T04:00:37-05:00
# 2   2018-11-17T04:00:31-05:00  2018-11-17T04:00:31-05:00
# 3   2018-11-17T04:00:26-05:00  2018-11-17T04:00:26-05:00
# 4   2018-11-17T04:00:26-05:00  2018-11-17T04:00:26-05:00
# 5   2018-11-17T04:00:24-05:00  2018-11-17T04:00:24-05:00
# 6   2018-11-17T04:00:11-05:00  2018-11-17T04:00:11-05:00
# 7   2018-11-16T20:57:25-05:00  2018-11-16T20:57:25-05:00
# 8   2018-11-16T15:57:01-05:00  2018-11-16T15:57:01-05:00
# 9   2018-11-16T15:56:59-05:00  2018-11-16T15:56:59-05:00
# 10  2018-11-16T14:16:51-05:00  2018-11-16T14:16:51-05:00
#
#                                                 title  \
# 0   Thanksgiving time: Anti-Trump media stuffing p...
# 1   Prison reform is on the horizon -- Now the Sen...
# 2   Call me the Thanksgiving Grinch -- here are fi...
# 3   Bill Bennett: The legacy of Saint Nicholas – W...
# 4   Steve Doocy: This Thanksgiving, here's what NO...
# 5   Amazon names new HQ2 – here's how citizens in ...
# 6         When God gives you more than you can handle
# 7   North Korean mystery weapons test creates poss...
# 8   Newt Gingrich: The left may be winning the war...
# 9   Sen. James Inhofe: A border wall can be built ...
# 10  Mark Penn: Congress needs to end partisan para...
#
#                                                   url
# 0   /opinion/thanksgiving-time-anti-trump-media-st...
# 1   /opinion/tim-head-prison-reform-is-on-the-hori...
# 2   /opinion/call-me-the-thanksgiving-grinch-here-...
# 3   /opinion/bill-bennett-the-legacy-of-saint-nich...
# 4   /opinion/steve-doocy-this-thanksgiving-heres-w...
# 5   /opinion/amazon-names-new-hq2-heres-how-citize...
# 6   /opinion/when-god-gives-you-more-than-you-can-...
# 7   /opinion/north-korean-mystery-weapons-test-cre...
# 8   /opinion/newt-gingrich-the-left-may-be-winning...
# 9   /opinion/sen-james-inhofe-a-border-wall-can-be...
# 10  /opinion/mark-penn-congress-needs-to-end-parti...

# %% [markdown]
# An offset of 1,000 takes us back about nine months.

# %%
url_off = url.replace('offset=30','offset=5000')

fox_df(url_off)
# Out:
# Return a df of length 11
#                                              category  \
# 0   {'name': 'POLITICS', 'url': '/category/politics'}
# 1   {'name': 'Bellwether', 'url': '/category/colum...
# 2   {'name': 'Solar Eclipse', 'url': '/category/sc...
# 3   {'name': 'Family', 'url': '/category/us/person...
# 4   {'name': 'Solar Eclipse', 'url': '/category/sc...
# 5   {'name': 'Solar Eclipse', 'url': '/category/sc...
# 6   {'name': 'Values', 'url': '/category/us/person...
# 7   {'name': 'Solar Eclipse', 'url': '/category/sc...
# 8   {'name': 'Health Care', 'url': '/category/poli...
# 9   {'name': 'POLITICS', 'url': '/category/politics'}
# 10  {'name': 'Values', 'url': '/category/us/person...
#
#                                           description duration  \
# 0   Americans have once again been subjected to a ...
# 1   As Spain and Finland cope with this week’s vio...
# 2   The Moon is about to come between the Earth an...
# 3   Be perfectly patient, perfectly calm, perfectl...
# 4   On Monday something will happen in the U.S. th...
# 5   Sun worship is not new, in fact, the 14th cent...
# 6   Listening to this cultural debate, it occurred...
# 7   Perhaps best of all, the eclipse has nothing a...
# 8   Few lawmakers are talking about the hidden hea...
# 9   Expanding their attacks, many longtime critics...
# 10  As a Cherokee, I can attest to the fact that N...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 2   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 3   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 4   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 5   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 6   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 7   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 8   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 9   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 10  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2017-09-25T22:19:48-04:00  2017-08-19T13:30:00-04:00
# 1   2017-09-25T22:19:37-04:00  2017-08-19T16:44:00-04:00
# 2   2017-09-25T22:01:29-04:00  2017-08-20T00:00:00-04:00
# 3   2017-09-25T22:01:18-04:00  2017-08-20T05:00:00-04:00
# 4   2017-09-25T22:01:07-04:00  2017-08-20T12:17:00-04:00
# 5   2017-09-25T22:00:56-04:00  2017-08-20T12:38:00-04:00
# 6   2017-09-25T22:00:45-04:00  2017-08-20T15:47:00-04:00
# 7   2017-09-25T22:00:33-04:00  2017-08-20T16:08:00-04:00
# 8   2017-09-25T21:24:07-04:00  2017-08-21T10:00:00-04:00
# 9   2017-09-25T21:23:57-04:00  2017-08-21T01:00:00-04:00
# 10  2017-09-25T21:23:46-04:00  2017-08-21T01:00:00-04:00
#
#                                                 title  \
# 0   Newt Gingrich: History is more important than ...
# 1            ISIS created by Israel? One imam says so
# 2   The eclipse of 2017 has nothing to do with pol...
# 3       Here's how moms can find relief from pressure
# 4                    Are solar eclipses proof of God?
# 5   Dr. Marc Siegel: Solar eclipse - science, safe...
# 6                     If America isn't great, who is?
# 7   The eclipse of 2017 has nothing to do with pol...
# 8   Another health care reform quandary -- What ab...
# 9   Trump is passing the ‘moral’ test when it come...
# 10  Congressman, Native American: When political c...
#
#                                                   url
# 0   /opinion/newt-gingrich-history-is-more-importa...
# 1    /opinion/isis-created-by-israel-one-imam-says-so
# 2   /opinion/the-eclipse-of-2017-has-nothing-to-do...
# 3   /opinion/heres-how-moms-can-find-relief-from-p...
# 4            /opinion/are-solar-eclipses-proof-of-god
# 5   /opinion/dr-marc-siegel-solar-eclipse-science-...
# 6               /opinion/if-america-isnt-great-who-is
# 7   /opinion/the-eclipse-of-2017-has-nothing-to-do...
# 8   /opinion/another-health-care-reform-quandary-w...
# 9   /opinion/trump-is-passing-the-moral-test-when-...
# 10  /opinion/congressman-native-american-when-poli...

# %% [markdown]
# 5,000 brings us back to 2017.

# %%
url_off = url.replace('offset=30','offset=10000')

fox_df(url_off)
# Out:
# Return a df of length 0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# But 10,000 fails. 😞.
#
# After attempting multiple values, it appears something around 9,950 is the maximum offset that will return results, which is approximately three years of data. This limit could be hard coded into the API or this could simply be all the data that is available on the website.

# %%
url_off = url.replace('offset=30','offset=9950')

fox_df(url_off)
# Out:
# Return a dataframe of length 11
#              category.name                                       category.url  \
# 0                   CANCER                            /category/health/cancer
# 1              Republicans           /category/politics/elections/republicans
# 2                   Values              /category/us/personal-freedoms/values
# 3   Presidential Primaries  /category/politics/elections/presidential-prim...
# 4                    Apple                     /category/tech/companies/apple
# 5              Middle East          /category/world/world-regions/middle-east
# 6                  Privacy                      /category/tech/topics/privacy
# 7   Presidential Primaries  /category/politics/elections/presidential-prim...
# 8                  Privacy                      /category/tech/topics/privacy
# 9                   Family              /category/us/personal-freedoms/family
# 10                  Family              /category/us/personal-freedoms/family
#
#                                           description duration  \
# 0   This month marks the fifth anniversary of the ...
# 1   Say this for the dim bulbs of the GOP: They fi...
# 2   Have you seen the revelation from former NFL s...
# 3   I refuse to play by Washington’s political rul...
# 4   Instead of lawyering up, Apple should mensch u...
# 5   Anniversaries are when we look back and see hi...
# 6   Today the line between public and private pers...
# 7   The inevitability of Hillary Clinton’s road to...
# 8   Donald Trump, Marco Rubio, Ted Cruz, Ben Carso...
# 9   I've now been married for 20 years. Standing o...
# 10  Maybe it was time to give away my “World’s Bes...
#
#                                              imageUrl  isBreaking  isLive  \
# 0   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 2   https://a57.foxnews.com/a57.foxnews.com/media2...       False   False
# 3   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 4   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 5   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 6   https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 7   https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 8   https://a57.foxnews.com/a57.foxnews.com/media2...       False   False
# 9   https://a57.foxnews.com///static.foxnews.com/s...       False   False
# 10  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
#
#             lastPublishedDate            publicationDate  \
# 0   2016-02-29T13:17:15-05:00  2016-02-29T12:57:00-05:00
# 1   2016-02-29T12:31:55-05:00  2016-02-29T10:19:00-05:00
# 2   2016-02-29T11:55:57-05:00  2016-02-26T12:15:00-05:00
# 3   2016-02-29T05:18:36-05:00  2016-02-29T02:30:00-05:00
# 4   2016-02-28T22:18:52-05:00  2016-02-25T14:39:00-05:00
# 5   2016-02-28T06:00:23-05:00  2016-02-28T06:00:00-05:00
# 6   2016-02-27T21:04:09-05:00  2016-02-27T18:00:00-05:00
# 7   2016-02-27T20:15:55-05:00  2016-02-27T20:00:00-05:00
# 8   2016-02-26T17:39:33-05:00  2016-02-26T16:15:00-05:00
# 9   2016-02-26T15:23:16-05:00  2016-02-26T11:50:00-05:00
# 10  2016-02-26T14:08:11-05:00  2016-02-26T14:00:00-05:00
#
#                                                 title  \
# 0   Cancer took my husband at 50. That's why the 2...
# 1   It's the end of the GOP as we know it if Trump...
# 2   Terry Crews and the dirty little secret of Pla...
# 3   Ben Carson: Why I intend to stay in the GOP pr...
# 4   What Apple's Tim Cook should learn from Facebo...
# 5   Why we won: Lessons from the Gulf War 25 years...
# 6   Will cancer patients be the next victims of th...
# 7   Hillary Clinton's South Carolina victory means...
# 8   Trump, Rubio, Cruz all want to repeal ObamaCar...
# 9   Looking back after twenty years of marriage: W...
# 10         Don't judge my family, I won't judge yours
#
#                                                   url
# 0   /opinion/cancer-took-my-husband-at-50-thats-wh...
# 1   /opinion/its-the-end-of-the-gop-as-we-know-it-...
# 2   /opinion/terry-crews-and-the-dirty-little-secr...
# 3   /opinion/ben-carson-why-i-intend-to-stay-in-th...
# 4   /opinion/what-apples-tim-cook-should-learn-fro...
# 5   /opinion/why-we-won-lessons-from-the-gulf-war-...
# 6   /opinion/will-cancer-patients-be-the-next-vict...
# 7   /opinion/hillary-clintons-south-carolina-victo...
# 8   /opinion/trump-rubio-cruz-all-want-to-repeal-o...
# 9   /opinion/looking-back-after-twenty-years-of-ma...
# 10   /opinion/dont-judge-my-family-i-wont-judge-yours

# %% [markdown]
# The final step in collecting the article metadata via the API is to make all the necessary API calls to gather all the relevant article metadata. I slightly revise the `fox_df` function so that it takes a value of an offset. I hardcoded the URL, fixing the size to 30.  A more robust function would turn the entire set of parameters into a dictionary that was modifiable. I also took out the print statement which would clutter the results.

# %%
def fox_df(offset):
    url = ('https://www.foxnews.com/api/article-search?'
           'isCategory=true&isTag=false&isKeyword=false&'
           'isFixed=false&isFeedUrl=false&searchSelected=opinion&'
           'contentTypes=%7B%22interactive%22:true,%22slideshow%22:true,%22video%22:false,%22article%22:true%7D&'
           'size=30&offset=0')
    
    url = url.replace('offset=0', 'offset=%s' % offset)
    
    r = requests.get(url)
    df = json_normalize(r.json())
    return df

# %% [markdown]
# Finally, I loop over the function. I create an empty dataframe and then append the results after each loop. I pause three seconds each pass in order to not access the web server too many times. The first time I ran this, I only retrieved a few pages of results to make sure everything worked.

# %%
from time import sleep # for pausing

# create empty dataframe to store results
fox_opinion_df = pd.DataFrame() 

# Create a loop that counts up by 30.
for offset in range(0, 1000, 30):
    new_df = fox_df(offset)
    
    # Add the new results to the existing database
    fox_opinion_df = fox_opinion_df.append(new_df, ignore_index=True)
    
    # Pause for three seconds to be polite to the web server
    sleep(3)

# %%
fox_opinion_df.tail()
# Out:
#                category.name                            category.url  \
# 1015                 OPINION                       /category/opinion
# 1016  Tucker Carlson Tonight  /category/shows/tucker-carlson-tonight
# 1017      The Ingraham Angle          /category/shows/ingraham-angle
# 1018                 OPINION                       /category/opinion
# 1019                 OPINION                       /category/opinion
#
#                                             description duration  \
# 1015  Republican Gov. Rick Scott leads Democratic Se...
# 1016  The race for Georgia governor was tight for mo...
# 1017  From Weinstein to Sharpton to Farrakhan and no...
# 1018  In Alcoholics Anonymous, we call Thanksgiving,...
# 1019  Michael Avenatti is accused of domestic violen...
#
#                                                imageUrl  isBreaking  isLive  \
# 1015  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1016  https://a57.foxnews.com/secure.media.foxnews.c...       False   False
# 1017  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
# 1018  https://a57.foxnews.com/static.foxnews.com/fox...       False   False
# 1019  https://a57.foxnews.com/media2.foxnews.com/Bri...       False   False
#
#               lastPublishedDate            publicationDate  \
# 1015  2018-11-16T08:14:18-05:00  2018-11-16T08:14:18-05:00
# 1016  2018-11-16T07:54:18-05:00  2018-11-16T07:53:30-05:00
# 1017  2018-11-16T07:13:30-05:00  2018-11-16T07:13:30-05:00
# 1018  2018-11-16T04:00:23-05:00  2018-11-16T04:00:23-05:00
# 1019  2018-11-15T22:07:56-05:00  2018-11-15T20:36:36-05:00
#
#                                                   title  \
# 1015  Marc Thiessen: Democrats in Florida know that ...
# 1016  Tucker Carlson: Accepting election outcomes yo...
# 1017  Laura Ingraham: Michael Avenatti's assault on ...
# 1018  How to navigate the 'Bermuda Triangle' of holi...
# 1019  Tammy Bruce: Avenatti demands fairness when he...
#
#                                                     url
# 1015  /opinion/marc-thiessen-democrats-in-florida-kn...
# 1016  /opinion/tucker-carlson-accepting-election-out...
# 1017  /opinion/laura-ingraham-michael-avenattis-assa...
# 1018  /opinion/avoiding-the-bermuda-triangle-of-holi...
# 1019  /opinion/tammy-bruce-avenatti-demands-fairness...

# %% [markdown]
# The dataframe can be stored as either as CSV file or JSON. CSV is best if you want to use it elsewhere, while a JSON usually is more robust to handling text strings which somtimes trip up CSV readers.

# %%
fox_opinion_df.to_csv('foxnews_opinion.csv')

# %%
fox_opinion_df.to_json('foxnews_opinion.json', orient ='records')

# %% [markdown]
# Things aren't always this easy, but when you stumble across an undocumented API you can quickly put together a dataset.
